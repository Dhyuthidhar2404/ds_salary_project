# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/PlayingNumbers/ds_salary_proj/master/glassdoor_jobs.csv")

# %%
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
#salary parsing
#state field
#company name text only
#age of company
#parsing of Job Description

# %% [markdown]
# # Salary Parsing

# %%
df.shape
# Out:
# (956, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         956 non-null    int64
#  1   Job Title          956 non-null    object
#  2   Salary Estimate    956 non-null    object
#  3   Job Description    956 non-null    object
#  4   Rating             956 non-null    float64
#  5   Company Name       956 non-null    object
#  6   Location           956 non-null    object
#  7   Headquarters       956 non-null    object
#  8   Size               956 non-null    object
#  9   Founded            956 non-null    int64
#  10  Type of ownership  956 non-null    object
#  11  Industry           956 non-null    object
#  12  Sector             956 non-null    object
#  13  Revenue            956 non-null    object
#  14  Competitors        956 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
df = df[df['Salary Estimate'] != '-1']
df.shape
# Out:
# (742, 15)

# %%
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0])
salary
# Out:
# 0       $53K-$91K
# 1      $63K-$112K
# 2       $80K-$90K
# 3       $56K-$97K
# 4      $86K-$143K
#           ...
# 950    $58K-$111K
# 951    $72K-$133K
# 952     $56K-$91K
# 953    $95K-$160K
# 955    $61K-$126K
# Name: Salary Estimate, Length: 742, dtype: object

# %%
minus_Kd = salary.apply(lambda x: x.replace('K','').replace('$',''))
minus_Kd
# Out:
# 0       53-91
# 1      63-112
# 2       80-90
# 3       56-97
# 4      86-143
#         ...
# 950    58-111
# 951    72-133
# 952     56-91
# 953    95-160
# 955    61-126
# Name: Salary Estimate, Length: 742, dtype: object

# %%
minus_Kd.unique()
# Out:
# array(['53-91 ', '63-112 ', '80-90 ', '56-97 ', '86-143 ', '71-119 ',
#        '54-93 ', '86-142 ', '38-84 ', '120-160 ', '126-201 ', '64-106 ',
#        '106-172 ', '46-85 ', '83-144 ', '102-190 ', '67-137 ', '118-189 ',
#        '110-175 ', '64-111 ', '81-130 ', '73-119 ', '86-139 ', '63-105 ',
#        '109-177 ', '63-110 ', '75-124 ', '34-61 ', '72-120 ', '93-149 ',
#        '85-140 ', '77-135 ', '82-132 ', '83-137 ', '115-180 ', '74-138 ',
#        '64-112 ', '68-129 ', '52-113 ', '110-150',
#        'Employer Provided Salary:150-160', '158-211 ', '20-39 ',
#        '56-117 ', '63-99 ', '68-114 ', '41-95 ', '86-144 ', '80-139 ',
#        '56-95 ', '120-189 ', '111-176 ', '84-146 ', '107-172 ', '49-85 ',
#        '61-109 ', '88-148 ', '60-99 ', '41-72 ', '96-161 ', '65-130 ',
#        '52-81 ', '139-220 ', '50-102 ', '85-139 ', '74-122 ', '99-157 ',
#        '79-222 ', '57-118 ', '86-141 ', '94-154 ', '37-76 ', '100-160 ',
# ...

# %%
df['hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df['hourly'].unique()
# Out:
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_10672\1492127727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
# array([0, 1], dtype=int64)

# %%
df['employer_provided'] = df['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)
df['employer_provided'].unique()
# Out:
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_10672\1340171498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['employer_provided'] = df['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)
# array([0, 1], dtype=int64)

# %%
min_hr = minus_Kd.apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary:',''))
min_hr.unique()
# Out:
# array(['53-91 ', '63-112 ', '80-90 ', '56-97 ', '86-143 ', '71-119 ',
#        '54-93 ', '86-142 ', '38-84 ', '120-160 ', '126-201 ', '64-106 ',
#        '106-172 ', '46-85 ', '83-144 ', '102-190 ', '67-137 ', '118-189 ',
#        '110-175 ', '64-111 ', '81-130 ', '73-119 ', '86-139 ', '63-105 ',
#        '109-177 ', '63-110 ', '75-124 ', '34-61 ', '72-120 ', '93-149 ',
#        '85-140 ', '77-135 ', '82-132 ', '83-137 ', '115-180 ', '74-138 ',
#        '64-112 ', '68-129 ', '52-113 ', '110-150', '150-160', '158-211 ',
#        '20-39 ', '56-117 ', '63-99 ', '68-114 ', '41-95 ', '86-144 ',
#        '80-139 ', '56-95 ', '120-189 ', '111-176 ', '84-146 ', '107-172 ',
#        '49-85 ', '61-109 ', '88-148 ', '60-99 ', '41-72 ', '96-161 ',
#        '65-130 ', '52-81 ', '139-220 ', '50-102 ', '85-139 ', '74-122 ',
#        '99-157 ', '79-222 ', '57-118 ', '86-141 ', '94-154 ', '37-76 ',
#        '100-160 ', '55-100 ', '60-114 ', '39-68 ', '64-107 ', '31-65 ',
# ...

# %%
df['min_Salary'] = min_hr.apply(lambda x: int(x.split('-')[0]))
df
# Out:
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_10672\3405576171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_Salary'] = min_hr.apply(lambda x: int(x.split('-')[0]))
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# ...

# %%
df['min_Salary'].dtype
# Out:
# dtype('int64')

# %%
df['max_Salary'] = min_hr.apply(lambda x: int(x.split('-')[1]))
df
# Out:
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_10672\956791156.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_Salary'] = min_hr.apply(lambda x: int(x.split('-')[1]))
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# ...

# %%
df['Average_Salary'] = (df.min_Salary + df.max_Salary)/2
df
# Out:
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_10672\4259150915.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Average_Salary'] = (df.min_Salary + df.max_Salary)/2
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# ...

# %%
filtered_df = df[df['Rating'] < 0]
company_names = filtered_df['Company Name'].tolist()
filtered_df
# Out:
#      Unnamed: 0                                          Job Title  \
# 208         208  Principal Data Scientist with over 10 years ex...
# 331         331  Principal Data Scientist with over 10 years ex...
# 377         377                               Data Operations Lead
# 472         472    Research Scientist, Immunology - Cancer Biology
# 518         518  Senior Scientist, Cell Pharmacology/Assay Deve...
# 583         583                                     Data Scientist
# 703         703    Research Scientist, Immunology - Cancer Biology
# 741         741      Scientist – Cancer Discovery, Molecular Assay
# 778         778  Senior Scientist, Cell Pharmacology/Assay Deve...
# 819         819  Principal Research Scientist/Team Lead, Medici...
# 943         943    Research Scientist, Immunology - Cancer Biology
#
#                           Salary Estimate  \
# 208  Employer Provided Salary:$200K-$250K
# 331  Employer Provided Salary:$200K-$250K
# ...

# %% [markdown]
# ## Company Name text only

# %%
df.loc[df['Rating'] < 0, 'Company_txt'] = df['Company Name']
df.loc[df['Rating'] >= 0, 'Company_txt'] = df['Company Name'].str[:-3]
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %% [markdown]
# ## State Field

# %%
#df['job_state'] = df['Location'].apply(lambda x: x.split(',')[1])
#df['job_state'] = df['Location'].str.split(',').str[1]
df.loc[:, 'job_state'] = df['Location'].str.split(',').str[1]
df
# Out:
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_10672\2595684234.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'job_state'] = df['Location'].str.split(',').str[1]
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 950         950           Sr Scientist, Immuno-Oncology - Oncology
# ...

# %%
#How many jobs are there for each state
df.job_state.value_counts()
# Out:
#  CA             151
#  MA             103
#  NY              72
#  VA              41
#  IL              40
#  MD              35
#  PA              33
#  TX              28
#  WA              21
#  NC              21
#  NJ              17
#  FL              16
#  OH              14
#  TN              13
#  DC              11
#  CO              11
#  WI              10
#  IN              10
#  UT              10
#  AZ               9
#  MO               9
#  AL               8
#  GA               6
#  KY               6
#  DE               6
#  MI               6
#  CT               5
#  IA               5
#  LA               4
#  OR               4
#  NE               4
#  NM               3
#  KS               3
#  ID               2
#  MN               2
#  Los Angeles      1
#  RI               1
#  SC               1
# Name: job_state, dtype: int64

# %%
#California has the highest jobs

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 742 entries, 0 to 955
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         742 non-null    int64
#  1   Job Title          742 non-null    object
#  2   Salary Estimate    742 non-null    object
#  3   Job Description    742 non-null    object
#  4   Rating             742 non-null    float64
#  5   Company Name       742 non-null    object
#  6   Location           742 non-null    object
#  7   Headquarters       742 non-null    object
#  8   Size               742 non-null    object
#  9   Founded            742 non-null    int64
#  10  Type of ownership  742 non-null    object
#  11  Industry           742 non-null    object
#  12  Sector             742 non-null    object
#  13  Revenue            742 non-null    object
#  14  Competitors        742 non-null    object
#  15  hourly             742 non-null    int64
# ...

# %% [markdown]
# ## Age of the Company

# %%
df.Founded.unique()
# Out:
# array([1973, 1984, 2010, 1965, 1998, 2000, 2008, 2005, 2014, 2009, 2011,
#        1968, 1962, 2012, 1781, 1995, 1915, 2013, 1935, 1849, 1952, 1852,
#        1997, 1996, 1974, 1969, 1870, 1985,   -1, 2015, 1993, 1958, 1986,
#        1999, 1925, 1912, 2002, 1863, 1939, 2016, 1885, 2006, 1948, 2003,
#        1927, 1978, 1860, 2017, 1942, 1990, 1988, 2001, 2007, 1992, 1994,
#        1977, 2019, 1982, 1937, 1878, 1966, 1971, 1943, 1987, 1945, 1846,
#        1851, 1976, 1981, 1970, 1951, 1967, 1961, 1964, 1930, 1917, 1883,
#        1887, 2004, 1850, 1902, 1744, 1929, 1947, 1991, 1989, 1928, 1875,
#        1913, 1972, 1856, 1983, 1922, 1812, 1914, 1980, 1954, 1830, 1975,
#        1899, 1979, 1889], dtype=int64)

# %%
#if there is -1 leave it like that and get the age for remaining ones.
from datetime import datetime

current_year = datetime.now().year
df['Company_Age'] = df.Founded.apply(lambda x: x if x<1 else current_year - x)
df
# Out:
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_10672\550029234.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company_Age'] = df.Founded.apply(lambda x: x if x<1 else current_year - x)
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_Salary', 'max_Salary',
#        'Average_Salary', 'Company_txt', 'job_state', 'Company_Age'],
#       dtype='object')

# %%
df['same_state'] = df.apply(lambda x: 1 if x.Location == x.Headquarters else 0, axis =1)
df
# Out:
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_10672\3661190162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['same_state'] = df.apply(lambda x: 1 if x.Location == x.Headquarters else 0, axis =1)
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# ...

# %% [markdown]
# ## Parsing of Job Description

# %%
#python
df['python_yn'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
#r studio
df['R_ys'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() else 0)
#spark
df['spark_ys'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
#aws
df['aws_ys'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
#excel
df['excel_ys'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
# Out:
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_10672\3855090362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['python_yn'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
# C:\Users\S.S.S.Dhyuthidhar\AppData\Local\Temp\ipykernel_10672\3855090362.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['R_ys'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() else 0)
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_Salary', 'max_Salary',
#        'Average_Salary', 'Company_txt', 'job_state', 'Company_Age',
#        'same_state', 'python_yn', 'R_ys', 'spark_ys', 'aws_ys', 'excel_ys'],
#       dtype='object')

# %%
df_out = df.drop(['Unnamed: 0'], axis = 1)
df_out
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 950  $58K-$111K (Glassdoor est.)
# ...

# %%
df_out.to_csv('Salary_Data_Cleaned.csv',index = False)
